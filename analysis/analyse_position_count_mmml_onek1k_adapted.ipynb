# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
ser = pd.read_json("../intersect_position_count_adapted.json", typ="series", dtype={str})
df = ser.to_frame("position_count")
df = df.reset_index(names="pos")
df[["chromosome", "position"]] = df["pos"].str.split("-", n=1, expand=True)
df.shape
# Out:
# (4115418, 4)

# %%
df["position_count"].sum()
# Out:
# 18889487

# %%
df.head()
# Out:
#           pos  position_count chromosome  position
# 0  9-21448448              12          9  21448448
# 1  9-21456776              13          9  21456776
# 2  9-21471499              15          9  21471499
# 3  9-21471726              17          9  21471726
# 4  9-21473817              14          9  21473817

# %%
df["chromosome"].nunique()
# Out:
# 22

# %%
threshold = 40

# %%
# plot with log scale
df["position_count"].plot(kind="hist", bins=88, xlabel="position count values", ylabel="frequency (log scale)")
plt.yscale('log')
#plt.axvline(x=threshold, color="r")

# %%
# plot without log scale
df["position_count"].plot(kind="hist", bins=49, xlabel="position count values", ylabel="frequency")
#plt.axvline(x=threshold, color="r")
# Out:
# <Axes: xlabel='position count values', ylabel='frequency'>

# %%
df["position_count"].median()
# Out:
# 3.0

# %%
df["position_count"].mean()
# Out:
# 4.589931569527081

# %%
df["position_count"].min()
# Out:
# 1

# %%
df["position_count"].max()
# Out:
# 88

# %%
plt.boxplot(df["position_count"])
#plt.yscale("log")
#plt.axhline(y=threshold)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f9404a60910>,
#   <matplotlib.lines.Line2D at 0x7f9404a60bb0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f940499f760>,
#   <matplotlib.lines.Line2D at 0x7f9404402dd0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f9404a60670>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f9404a60d60>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f9404a61000>],
#  'means': []}
