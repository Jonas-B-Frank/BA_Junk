# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
ser = pd.read_json("../intersect_position_count.json", typ="series", dtype={str})
df = ser.to_frame("position_count")
df = df.reset_index(names="pos")
df[["chromosome", "position"]] = df["pos"].str.split("-", n=1, expand=True)
df.shape
# Out:
# (4106598, 4)

# %%
df["position_count"].sum()
# Out:
# 18822150

# %%
df.head()
# Out:
#           pos  position_count chromosome  position
# 0  9-21448447              12          9  21448447
# 1  9-21456775              14          9  21456775
# 2  9-21471498              15          9  21471498
# 3  9-21471725              17          9  21471725
# 4  9-21473816              14          9  21473816

# %%
df["chromosome"].nunique()
# Out:
# 22

# %%
threshold = 10

# %%
# plot with log scale
df["position_count"].plot(kind="hist", bins=49, xlabel="position count values", ylabel="frequency (log scale)")
plt.yscale('log')
#plt.axvline(x=threshold, color="r")

# %%
# plot without log scale
df["position_count"].plot(kind="hist", bins=49, xlabel="position count values", ylabel="frequency")
#plt.axvline(x=threshold, color="r")
# Out:
# <Axes: xlabel='position count values', ylabel='frequency'>

# %%
df["position_count"].median()
# Out:
# 3.0

# %%
df["position_count"].mean()
# Out:
# 4.583392384645393

# %%
df["position_count"].min()
# Out:
# 1

# %%
df["position_count"].max()
# Out:
# 49

# %%
plt.boxplot(df["position_count"])
#plt.yscale("log")
#plt.axhline(y=threshold)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fe139bc0ca0>,
#   <matplotlib.lines.Line2D at 0x7fe139bc0f40>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fe139bc11e0>,
#   <matplotlib.lines.Line2D at 0x7fe139bc1480>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7fe1399fb9d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fe139bc1720>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fe139bc19c0>],
#  'means': []}
