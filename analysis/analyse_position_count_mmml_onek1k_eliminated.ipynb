# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
ser = pd.read_json("../intersect_position_count_eliminated.json", typ="series", dtype={str})
df = ser.to_frame("position_count")
df = df.reset_index(names="pos")
df[["chromosome", "position"]] = df["pos"].str.split("-", n=1, expand=True)
df.shape
# Out:
# (65563, 4)

# %%
df["position_count"].sum()
# Out:
# 269869

# %%
df.head()
# Out:
#            pos  position_count chromosome   position
# 0  1-100002713               1          1  100002713
# 1  1-100059600               1          1  100059600
# 2  1-100069552               1          1  100069552
# 3  1-100074270               1          1  100074270
# 4  1-100147389               1          1  100147389

# %%
df["chromosome"].nunique()
# Out:
# 22

# %%
threshold = 40

# %%
# plot with log scale
df["position_count"].plot(kind="hist", bins=88, xlabel="position count values", ylabel="frequency (log scale)")
plt.yscale('log')
#plt.axvline(x=threshold, color="r")

# %%
# plot without log scale
df["position_count"].plot(kind="hist", bins=49, xlabel="position count values", ylabel="frequency")
#plt.axvline(x=threshold, color="r")
# Out:
# <Axes: xlabel='position count values', ylabel='frequency'>

# %%
df["position_count"].median()
# Out:
# 2.0

# %%
df["position_count"].mean()
# Out:
# 4.116178332291079

# %%
df["position_count"].min()
# Out:
# 1

# %%
df["position_count"].max()
# Out:
# 44

# %%
plt.boxplot(df["position_count"])
#plt.yscale("log")
#plt.axhline(y=threshold)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f85bf999630>,
#   <matplotlib.lines.Line2D at 0x7f85bf999780>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f85bf999a50>,
#   <matplotlib.lines.Line2D at 0x7f85bf999cf0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f85bf9985e0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f85bf999f90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f85bf99a230>],
#  'means': []}
